# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('ErrorAnalysis_ofApproxAdders(CompleteData).csv')
df['ER'] = df['ER'].str.replace('%', '').astype(float)
df
# Out:
#           Design     ER     MED  MRED  NMED (in 10^-3)         Power  \
# 0    HOERAA(K=6)  99.71  386.63  5.89             5.90  9.450000e-07
# 1    HOERAA(K=7)  99.41  193.69  5.17             2.96  1.110000e-06
# 2    HOERAA(K=8)  98.83   96.49  4.45             1.47  1.280000e-06
# 3    HOERAA(K=9)  97.66   48.16  3.73             0.73  1.440000e-06
# 4   HOERAA(K=10)  95.31   24.07  2.98             0.37  1.610000e-06
# ..           ...    ...     ...   ...              ...           ...
# 58    OLOCA(K=8)  99.12  116.51  4.45             1.78           NaN
# 59    OLOCA(K=9)  98.83   64.15  3.73             0.98           NaN
# 60   OLOCA(K=10)  97.66   32.08  2.98             0.49           NaN
# 61   OLOCA(K=11)  95.31   15.84  2.25             0.24           NaN
# 62   OLOCA(K=12)  90.63    7.73  1.47             0.12           NaN
#
#     Delay (in ps)  Power-NMED  Energy-NMED  EDP-NMED
# 0           298.0         NaN          NaN       NaN
# 1           341.0         NaN          NaN       NaN
# 2           384.0         NaN          NaN       NaN
# 3           428.0         NaN          NaN       NaN
# 4           471.0         NaN          NaN       NaN
# ..            ...         ...          ...       ...
# 58            NaN         NaN          NaN       NaN
# 59            NaN         NaN          NaN       NaN
# 60            NaN         NaN          NaN       NaN
# 61            NaN         NaN          NaN       NaN
# 62            NaN         NaN          NaN       NaN
#
# [63 rows x 10 columns]

# %%
models = range(6, 13)  # Corresponding to K values from 6 to 12
data_types = ["LOA", "LOAWA", "OLOCA", "HOERAA", "ETAI", "CPETA", "ECPETA", "HERLOA"]

# Initialize a dictionary to store data
data = {dtype: [] for dtype in data_types}

# Populate the dictionary with error rates for each model
for dtype in data_types:
    for k in models:
        # Find the design matching the current type and K value
        design_key = f"{dtype}(K={k})"
        error_rate = df.loc[df['Design'] == design_key, 'ER'].values
        data[dtype].append(error_rate[0] if len(error_rate) > 0 else None)
data
# Out:
# {'LOA': [94.34, 92.48, 89.98, 86.63, 82.18, 76.24, 68.34],
#  'LOAWA': [94.34, 92.48, 89.98, 86.63, 82.18, 76.24, 68.34],
#  'OLOCA': [99.51, 99.34, 99.12, 98.83, 97.66, 95.31, 90.63],
#  'HOERAA': [99.71, 99.41, 98.83, 97.66, 95.31, 90.63, 81.25],
#  'ETAI': [94.34, 92.48, 89.98, 86.63, 82.18, 76.24, 68.34],
#  'CPETA': [92.48, 89.98, 86.63, 82.18, 76.24, 68.34, 57.8],
#  'ECPETA': [92.48, 89.98, 86.63, 82.18, 76.24, 68.34, 57.8],
#  'HERLOA': [91.25, 88.31, 84.39, 79.22, 72.29, 63.07, 50.77]}

# %%
eqn=[]

for k in models:
    eqn.append((1-(7/8)*(3/4)**(14-k))*100)
# Plotting
bar_width = 0.1
x_labels = np.arange(len(models))

# Create the bar graph
plt.figure(figsize=(15, 8))
plt.ylim(40,100)

colors = ['orange', 'lightblue', 'green', 'black', 'grey', 'blue', 'brown', 'yellow']

for i, dtype in enumerate(data_types):
    values = [value if value is not None else 0 for value in data[dtype]]
    plt.bar(x_labels + i * bar_width, values, width=bar_width, label=dtype, color=colors[i])

plt.plot(x_labels + bar_width * (len(data_types) - 1) / 2, eqn, color='blue', label='Equation2', marker='x', linestyle='--', linewidth=2)

# Customizations
plt.xticks(x_labels + bar_width * (len(data_types) - 1) / 2, models, rotation=45, fontsize=10)
plt.ylabel("Error Rate (%)", fontsize=12)
plt.xlabel("k", fontsize=12)
plt.title("Comparison of error rates of 16-bit approximate adders at various values of design parameter k", fontsize=14)
plt.legend(title="", fontsize=10)

# Show the plot
plt.tight_layout()
plt.savefig("fig6.png", dpi=300)

plt.show()

# %%
data_types.remove('HERLOA')

data = {dtype: [] for dtype in data_types}

for dtype in data_types:
    for k in models:
        # Design key for current type and K value
        design_key = f"{dtype}(K={k})"
        
        # Find MED for the current design and HERLOA design for the same K value
        MED_current = df.loc[df['Design'] == design_key, 'MED'].values
        MED_HERLOA = df.loc[df['Design'] == f"HERLOA(K={k})", 'MED'].values
        
        # Check if both current MED and HERLOA MED are available, then calculate the % improvement
        if len(MED_current) > 0 and len(MED_HERLOA) > 0:
            improvement = ((MED_current[0]-MED_HERLOA[0]) / MED_HERLOA[0]) * 100
            data[dtype].append(improvement)
        else:
            data[dtype].append(None)

# The 'data' dictionary now contains the percentage improvements with respect to HERLOA
print(data)
# Out:
# {'LOA': [29.548011191554412, 30.027675276752774, 30.24576860653836, 30.461108523521208, 30.89887640449439, 32.14629451395572, 34.95934959349593], 'LOAWA': [118.97083850125472, 122.58994464944651, 124.14792487827498, 124.05682347461573, 124.29775280898876, 129.35514918190566, 135.97560975609755], 'OLOCA': [29.233609276298715, 30.708025830258297, 35.06839786691398, 49.394503959012596, 50.187265917603, 52.454282964388824, 57.11382113821139], 'HOERAA': [11.520378436066803, 11.6755073800738, 11.859494551356352, 12.156497438285978, 12.687265917603, 13.859480269489888, 15.853658536585371], 'ETAI': [104.77083273241223, 108.14690959409594, 109.68003709714816, 109.7345132743363, 110.34644194756555, 115.88065447545715, 123.57723577235772], 'CPETA': [4.13049121693732, 4.283902214022144, 4.405286343612332, 4.634373544480676, 5.009363295880151, 5.87102983638113, 7.317073170731714], 'ECPETA': [-5.970751968617494, -5.506226937269379, -5.460236494319508, -5.030274802049363, -5.2434456928839, -3.657362848893174, -4.268292682926829]}

# %%
bar_width = 0.1
x_labels = np.arange(len(models))

# Create the bar graph
plt.figure(figsize=(15, 8))

colors = ['orange', 'yellow', 'lightblue', 'brown', 'grey', 'green', 'blue']

for i, dtype in enumerate(data_types):
    values = [value if value is not None else 0 for value in data[dtype]]
    plt.bar(x_labels + i * bar_width, values, width=bar_width, label=dtype, color=colors[i])

# Customizations
plt.xticks(x_labels + bar_width * (len(data_types) - 1) / 2, models, rotation=45, fontsize=10)
plt.ylabel("MED improvement (%)", fontsize=12)
plt.xlabel("k", fontsize=12)
plt.title("Improvements in the mean error distance (MED) of the proposed HERLOA in comparison with those of seven approximate adders at various values of k.", fontsize=14)
plt.legend(title="", fontsize=10)

# Show the plot
plt.tight_layout()
plt.savefig("fig7.png", dpi=300)

plt.show()
